# %% [raw]
# This Tool CRAWLS www.bloomberg.com to retrieve company details.
#
# The idea is to get information from BTRD to show on the fundamental screen upon user request.
#
#
#
#
# ****************    NZX       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 19370                NaN          AIA:NZ               NZX
# 19422                NaN          CEN:NZ               NZX
# 19744                NaN          RYM:NZ               NZX
# 19794                NaN          SKT:NZ               NZX
# 19847                NaN          TEL:NZ               NZX
# 19880                NaN          TME:NZ               NZX
# 27495               'TEL          TEL:NZ               NZX
# 29230            'CEN.NZ          CEN:NZ               NZX
# 29239            'FBU.NZ          FBU:NZ               NZX
# 29247            'AIA.NZ          AIA:NZ               NZX
# ****************    London Intl       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 19395                NaN          JS8:LI       London Intl
# 19806                NaN          CC3:LI       London Intl
# 19924                NaN          BS6:LI       London Intl
# 29149           'SMSN.LI         SMSN:LI       London Intl
# 29153           'HHPD.LI         HHPD:LI       London Intl
# 29164           'RIGD LI         RIGD:LI       London Intl
# 29198           'LTOD.LI         LTOD:LI       London Intl
# 30210           'LKOD.LI         LKOD:LI       London Intl
# 30218           'NVTK LI         NVTK:LI       London Intl
# 30277           'MGNT.LI         MGNT:LI       London Intl
# ****************    Singapore       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 19479                NaN         GENS:SP         Singapore
# 19710                NaN         OLAM:SP         Singapore
# 19725                NaN         OCBC:SP         Singapore
# 19753                NaN         SATS:SP         Singapore
# 27489               'SPH          SPH:SP         Singapore
# 28684               'GLP          GLP:SP         Singapore
# 28685               'HKL          HKL:SP         Singapore
# 28690              'CAPL         CAPL:SP         Singapore
# 28709                'CT           CT:SP         Singapore
# 28711             'AREIT        AREIT:SP         Singapore
# ****************    Copenhagen       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 20839                NaN      MAERSKB:DC        Copenhagen
# 20957                NaN        CARLB:DC        Copenhagen
# 20977                NaN        COLOB:DC        Copenhagen
# 20989                NaN       DANSKE:DC        Copenhagen
# 21012                NaN          DSV:DC        Copenhagen
# 21048                NaN          FLS:DC        Copenhagen
# 21078                NaN           GN:DC        Copenhagen
# 21150                NaN         JYSK:DC        Copenhagen
# 21217                NaN          NDA:DC        Copenhagen
# 21220                NaN        NOVOB:DC        Copenhagen
# ****************    Stockholm       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 20841                NaN          ABB:SS         Stockholm
# 20863                NaN         ALFA:SS         Stockholm
# 20882                NaN        ASSAB:SS         Stockholm
# 20887                NaN        ATCOA:SS         Stockholm
# 20931                NaN          BOL:SS         Stockholm
# 20961                NaN         CAST:SS         Stockholm
# 21024                NaN        ELUXB:SS         Stockholm
# 21025                NaN        EKTAB:SS         Stockholm
# 21034                NaN        ERICB:SS         Stockholm
# 21071                NaN        GETIB:SS         Stockholm
# ****************    Oslo       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 20860                NaN         AKSO:NO              Oslo
# 21009                NaN          DNB:NO              Oslo
# 21073                NaN          GJF:NO              Oslo
# 21190                NaN          MHG:NO              Oslo
# 21218                NaN          NHY:NO              Oslo
# 21231                NaN          ORK:NO              Oslo
# 21244                NaN          PGS:NO              Oslo
# 21307                NaN         SDRL:NO              Oslo
# 21339                NaN          STL:NO              Oslo
# 21342                NaN          STB:NO              Oslo
# ****************    Helsinki       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 20868                NaN        AMEAS:FH          Helsinki
# 21027                NaN        ELI1V:FH          Helsinki
# 21051                NaN        FUM1V:FH          Helsinki
# 21155                NaN        KRA1V:FH          Helsinki
# 21158                NaN        KESBV:FH          Helsinki
# 21163                NaN        KNEBV:FH          Helsinki
# 21164                NaN        KCR1V:FH          Helsinki
# 21199                NaN        MEO1V:FH          Helsinki
# 21212                NaN        NES1V:FH          Helsinki
# 21215                NaN        NOK1V:FH          Helsinki
# ****************    Vienna       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 20870                NaN         ANDR:AV            Vienna
# 21035                NaN          EBS:AV            Vienna
# 21122                NaN          IIA:AV            Vienna
# 21226                NaN          OMV:AV            Vienna
# 21369                NaN          TKA:AV            Vienna
# 21410                NaN          VIG:AV            Vienna
# 21415                NaN          VOE:AV            Vienna
# 29818            'VIG.AV          VIG:AV            Vienna
# 29821            'EBS AV          EBS:AV            Vienna
# 29840            'VOE.AV          VOE:AV            Vienna
# ****************    OTC  US       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 21408                NaN        VWDRY:US           OTC  US
# 25739             'SUBCY        SUBCY:US           OTC  US
# 25746             'WOSYY        WOSYY:US           OTC  US
# 25750             'AHONY        AHONY:US           OTC  US
# 25755             'BSYBY        BSYBY:US           OTC  US
# 25760             'VOLVY        VOLVY:US           OTC  US
# 25890             'NVZMY        NVZMY:US           OTC  US
# 25898             'STRNY        STRNY:US           OTC  US
# 25899             'TOTDY        TOTDY:US           OTC  US
# 25930             'DWAHY        DWAHY:US           OTC  US
# ****************    NYSE Arca       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 25650                NaN         ACCU:US         NYSE Arca
# 25651               'EWJ          EWJ:US         NYSE Arca
# 25652               'EWY          EWY:US         NYSE Arca
# 25653              'MCHI         MCHI:US         NYSE Arca
# 25654              'ERUS         ERUS:US         NYSE Arca
# 25655               'EWG          EWG:US         NYSE Arca
# 25658                NaN         AGLS:US         NYSE Arca
# 25665               'EZA          EZA:US         NYSE Arca
# 25666               'EWO          EWO:US         NYSE Arca
# 25667               'EWT          EWT:US         NYSE Arca
# ****************    BATS       **************
#        Constituent Ticker BloombergSymbol BloombergExchange
# 27130               'EWUS         EWUS:US              BATS
# 27148               'SMIN         SMIN:US              BATS
# 72687                 NaN         QLTC:US              BATS
# 72905                 NaN         QLTB:US              BATS
# 97838                 NaN         CEMB:US              BATS
# 98174                 NaN         EMHY:US              BATS
# 101435                NaN         HYXU:US              BATS
# 101707                NaN         GHYG:US              BATS
# 107059                NaN         IYLD:US              BATS
# 113555                NaN         EWAS:US              BATS
# ****************    Tel Aviv       **************
#       Constituent Ticker BloombergSymbol BloombergExchange
# 27488               'ICL          ICL:IT          Tel Aviv
# 29634           'TEVA.IT         TEVA:IT          Tel Aviv
# 30026           'POLI.IT         POLI:IT          Tel Aviv
# 35972          'DLEKG-IL        DLEKG:IT          Tel Aviv
# 37572           'DSCT.IT         DSCT:IT          Tel Aviv
